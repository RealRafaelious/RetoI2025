# %% [markdown]
# RETO 1 CEIBAL

# %%
from Limpieza import LimpiarCentros # si LimpiarCentros.py contiene la lógica de limpieza
from Limpieza import LimpiarDocentes
from Limpieza import LimpiarEstudiantes 

#Primero se llama a los scripts de limpieza de datos 
LimpiarCentros
LimpiarDocentes
LimpiarEstudiantes
# Out:
# Valores únicos después de limpiar:
# ['Quintil 3' 'Quintil 5' 'Quintil 1' 'Quintil 4' 'Quintil 2'
#  'sin identificar']
#
# Cantidad de "sin identificar": 7
# Total de filas: 260
#
# Guardando en: c:\Users\Estudiante UCU\Repositorios\RetoI2025\TablasActuales\Tabla_centros_7moa9no_limpia.xlsx
#
# Archivo guardado correctamente.
# Filas eliminadas por valores nulos en columnas críticas: 0
# Filas restantes después de eliminar nulos: 48673
# Edad promedio de docentes (en datos limpios antes de corregir menores): 40.92
# Se detectaron y corrigieron 5 docentes con edad menor a 18. Ahora tienen edad = 41.
#
# --- RESUMEN DE LA LIMPIEZA ---
# Limpieza completada.
# Docentes válidos guardados: 11700
# Docentes con datos 'desconocido' (ya sean duplicados o únicos) separados: 27
# Cantidad de celdas con valor "desconocido" en el DataFrame final (debería ser 0): 0
# Archivo 'c:\Users\Estudiante UCU\Repositorios\RetoI2025\Limpieza\..\TablasIniciales\Tabla_estudiantes_7moa9no.xlsx' cargado exitosamente!
# Nombres de columnas limpiados exitosamente.
# Columna 'grupo' normalizada.
#
# --- Iniciando formateo de fechas ---
# Columna 'primera_conexion_crea' ya está en formato de fecha. No se requiere conversión.
# Columna 'primera_conexion_dispositivo' ya está en formato de fecha. No se requiere conversión.
# --- Fin formateo de fechas ---
#
# Columna 'primera_conexion_crea' formateada a string para exportación a Excel.
# Columna 'primera_conexion_dispositivo' formateada a string para exportación a Excel.
# Estudiantes válidos guardados en: 'c:\Users\Estudiante UCU\Repositorios\RetoI2025\Limpieza\..\TablasActuales\Tabla_estudiantes_7moa9no_limpia.xlsx'
# Estudiantes con solo datos 'desconocido' separados en: 'c:\Users\Estudiante UCU\Repositorios\RetoI2025\Limpieza\..\Segregaciones\Estudiantes_solo_desconocidos.xlsx'
#
# --- Resumen de la Limpieza ---
# Limpieza completada.
# Estudiantes válidos guardados: 95332
# Estudiantes con solo datos 'desconocido' separados: 9
# Cantidad total de celdas con valor "desconocido" (antes de la segregación final): 6863
# ----------------------------
# <module 'Limpieza.LimpiarEstudiantes' from 'c:\\Users\\Estudiante UCU\\Repositorios\\RetoI2025\\Limpieza\\LimpiarEstudiantes.py'>

# %% [markdown]
# PREGUNTA UNO 1. ¿Varía el uso de la plataforma CREA según el grado educativo? ¿Hay diferencias por sexo?

# %%
from Preguntas import ConexionPorGradoEducativo

ConexionPorGradoEducativo
# Out:
# <module 'Preguntas.ConexionPorGradoEducativo' from 'c:\\Users\\Estudiante UCU\\Repositorios\\RetoI2025\\Preguntas\\ConexionPorGradoEducativo.py'>

# %% [markdown]
# Pregunta 2. ¿Hay diferencia entre el uso de CREA y la conexión por dispositivo? ¿Correlacionan?

# %%
from Preguntas import ConexionesCreaDispositivo

ConexionesCreaDispositivo
# Out:
#        cr_total_dias_ingreso  dias_de_conexion_dispositivo
# count           88041.000000                  50569.000000
# mean               57.459627                    100.161107
# std                31.253248                     69.890728
# min                10.000000                      1.000000
# 25%                34.000000                     42.000000
# 50%                53.000000                     89.000000
# 75%                76.000000                    149.000000
# max               284.000000                    306.000000
# Correlación Pearson entre primera conexión CREA y primera conexión dispositivo: 0.133
# P-valor: 4.007e-200
# N observaciones: 51217
# Correlación estadísticamente significativa.
#
# Promedio días ingreso (total): 57.46
# Promedio días de conexión dispositivo: 100.16
# <module 'Preguntas.ConexionesCreaDispositivo' from 'c:\\Users\\Estudiante UCU\\Repositorios\\RetoI2025\\Preguntas\\ConexionesCreaDispositivo.py'>

# %% [markdown]
# Pregunta 3. ¿Hay diferencias de uso del dispositivo y de CREA por contextos de vulnerabilidad?

# %% [markdown]
# Pregunta 4. ¿Los estudiantes que comparten docente muestran patrones de uso similares?

# %% [markdown]
# Pregunta 4. ¿Los estudiantes que comparten docente muestran patrones de uso similares?

# %%
from Preguntas import PatronesDeEstudiantesPorDocentes
PatronesDeEstudiantesPorDocentes
# Out:
# 📊 Promedio conexión (docente mujer): 100.45
# 📊 Promedio conexión (docente varón): 99.62
# 🔬 p-valor: 0.2028
# ❌ No hay evidencia significativa de que influya el sexo del docente.
# c:\Users\Estudiante UCU\Repositorios\RetoI2025\Preguntas\PatronesDeEstudiantesPorDocentes.py:40: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_filtrado, x="sexo_docente", y="dias_de_conexion_dispositivo", palette="pastel")
# <module 'Preguntas.PatronesDeEstudiantesPorDocentes' from 'c:\\Users\\Estudiante UCU\\Repositorios\\RetoI2025\\Preguntas\\PatronesDeEstudiantesPorDocentes.py'>
